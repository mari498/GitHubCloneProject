# %% [markdown]
# <a href="https://colab.research.google.com/github/mari498/GitHubCloneProject/blob/main/Strings/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#تعريف الايام والمواعيد و الخدمات
Days = ['الاحد', 'الاثنين', 'الثلثاء', 'الاربعاء', 'الخميس']
Times = ['9:00','10:00','11:00','12:00','01:00']
MAX_BOOKINGS_PER_SLOT=10

SERVICES = {
    '1''اصدار رخصه سيارة اول مرة'
    '2''تجديد رخصه سيارة'
    '3''اصدار رخصه قياده اول مرة'
    '4''تجديد رخصه قيادة'
    '5''اصدار بدل فاقد'
}

#انشاء جدول حجز
def initialize_bookings():
    bookings = {}
    for service in SERVICES:
        bookings[service] = {}
    for day in Days:
        bookings[day] = {}
        for time in Times:
            bookings [service][day][time] = 0
    return bookings

    def display_services():
       print("\nالخدمات المتاحة:")
       for key , value in SERVICES.items():
           print(f"{key}. {value}")
    def display_services():
       print("\nالخدمات المتاحة:")
       for i, service in enumerate(SERVICES, start=1):
           print(f"{i}. {service}")


    def show_bookings_for_service(bookings, service_name):
      print(f"حجوزات {service_name}:")
      for day in Days:
        print(f"{day}:")
        for time in Times:
          count = bookings[service_name][day][time]
          print(f" {time} - {count}\10 حجوزات")

def make_booking(bookings, service_name, day, time):
    if bookings[service_name][day][time] < MAX_BOOKINGS_PER_SLOT:
        bookings[service_name][day][time] += 1
        print(f"تم حجز {service_name} في {day} في {time}.")
    else:
      print("هذا الموعد ممتلى بالفعل ")


      def main():
        bookings = initialize_bookings()

        while True:
           display_services()
           choice = input ("\n اختر رقم الخدمه(او اكتب 'خروج' لانهاء البرنامج )").sptrip()
           if choice.lower() == 'خروج':
            print("شكرا لاستخدامك النظام")
            break


            if choice not in SERVICES:
              print("خيار غير صالح ,حاول مرة اخري")
              continue

              service_name = SERVICES[choice]
              show_bookings_for_service(bookings, service_name)
            day = input("\nاختر يوم من :(الاحد - الخميس)").strip()
            if day not in Days:
              print("يجب اختيار يوم من القائمة")
              continue

           time = input("ختر وقت من :(1:00),(12:00),(11:00),(10:00),(9:00)").strip()
           if time not in Times:
             print("يجب اختيار وقت من القائمة")
             continue

             make_booking(bookings, service_name, day, time)
             show_bookings_for_service(bookings, service_name)
#تعريف الايام والمواعيد و الخدمات
Days = ['الاحد', 'الاثنين', 'الثلثاء', 'الاربعاء', 'الخميس']
Times = ['9:00','10:00','11:00','12:00','01:00']
MAX_BOOKINGS_PER_SLOT=10

SERVICES = {
    '1': 'اصدار رخصه سيارة اول مرة',
    '2': 'تجديد رخصه سيارة',
    '3': 'اصدار رخصه قياده اول مرة',
    '4': 'تجديد رخصه قيادة',
    '5': 'اصدار بدل فاقد'
}

#انشاء جدول حجز
def initialize_bookings():
    bookings = {}
    for service in SERVICES:
        bookings[service] = {}
        for day in Days:
            bookings[service][day] = {}
            for time in Times:
                bookings [service][day][time] = 0
    return bookings

def display_services():
    print("\nالخدمات المتاحة:")
    for key , value in SERVICES.items():
        print(f"{key}. {value}")

def show_bookings_for_service(bookings, service_id):
    service_name = SERVICES[service_id]
    print(f"حجوزات {service_name}:")
    for day in Days:
        print(f"{day}:")
        for time in Times:
            count = bookings[service_id][day][time]
            print(f" {time} - {count}/10 حجوزات")

def make_booking(bookings, service_id, day, time):
    if bookings[service_id][day][time] < MAX_BOOKINGS_PER_SLOT:
        bookings[service_id][day][time] += 1
        service_name = SERVICES[service_id]
        print(f"تم حجز {service_name} في {day} في {time}.")
    else:
      print("هذا الموعد ممتلى بالفعل ")


def main():
    bookings = initialize_bookings()

    while True:
        display_services()
        choice = input ("\n اختر رقم الخدمه(او اكتب 'خروج' لانهاء البرنامج )").strip()
        if choice.lower() == 'خروج':
            print("شكرا لاستخدامك النظام")
            break

        if choice not in SERVICES:
            print("خيار غير صالح ,حاول مرة اخري")
            continue

        show_bookings_for_service(bookings, choice)

        day = input("\nاختر يوم من :(الاحد - الخميس)").strip()
        if day not in Days:
            print("يجب اختيار يوم من القائمة")
            continue

        time = input("ختر وقت من :(1:00),(12:00),(11:00),(10:00),(9:00)").strip()
        if time not in Times:
            print("يجب اختيار وقت من القائمة")
            continue

        make_booking(bookings, choice, day, time)
        show_bookings_for_service(bookings, choice)
        appointmenters=0


if __name__ == "__main__":
    main()


    appointmentes[الاحد][9:00]=5
    appointmentes[الاثنين][9:00]=7
    appointmentes[الثلثاء][9:00]=9
    appointmentes[الاربعاء][9:00]=1
    appointmentes[الخميس][9:00]=10
    appointmentes[الاحد][10:00]=4
    appointmentes[الاثنين][10:00]=6
    appointmentes[الثلثاء][10:00]=8
    appointmentes[الاربعاء][10:00]=0
    appointmentes[الخميس][10:00]=10
    appointmentes[الاحد][11:00]=7
    appointmentes[الاثنين][11:00]=9
    appointmentes[الثلثاء][11:00]=10
    appointmentes[الاربعاء][11:00]=7
    appointmentes[الخميس][11:00]=4
    appointmentes[الاحد][12:00]=9
    appointmentes[الاثنين][12:00]=10
    appointmentes[الثلثاء][12:00]=1
#تعريف الايام والمواعيد و الخدمات
Days = ['الاحد', 'الاثنين', 'الثلثاء', 'الاربعاء', 'الخميس']
Times = ['9:00','10:00','11:00','12:00','01:00']
MAX_BOOKINGS_PER_SLOT=10

SERVICES = {
    '1': 'اصدار رخصه سيارة اول مرة',
    '2': 'تجديد رخصه سيارة',
    '3': 'اصدار رخصه قياده اول مرة',
    '4': 'تجديد رخصه قيادة',
    '5': 'اصدار بدل فاقد'
}

#انشاء جدول حجز
def initialize_bookings():
    bookings = {}
    for service in SERVICES:
        bookings[service] = {}
        for day in Days:
            bookings[service][day] = {}
            for time in Times:
                bookings [service][day][time] = 0
    return bookings

def display_services():
    print("\nالخدمات المتاحة:")
    for key , value in SERVICES.items():
        print(f"{key}. {value}")

def show_bookings_for_service(bookings, service_id):
    service_name = SERVICES[service_id]
    print(f"حجوزات {service_name}:")
    for day in Days:
        print(f"{day}:")
        for time in Times:
            count = bookings[service_id][day][time]
            print(f" {time} - {count}/10 حجوزات")

def make_booking(bookings, service_id, day, time):
    if bookings[service_id][day][time] < MAX_BOOKINGS_PER_SLOT:
        bookings[service_id][day][time] += 1
        service_name = SERVICES[service_id]
        print(f"تم حجز {service_name} في {day} في {time}.")
    else:
      print("هذا الموعد ممتلى بالفعل ")


def main():
    bookings = initialize_bookings()

    while True:
        display_services()
        choice = input ("\n اختر رقم الخدمه(او اكتب 'خروج' لانهاء البرنامج )").strip()
        if choice.lower() == 'خروج':
            print("شكرا لاستخدامك النظام")
            break

        if choice not in SERVICES:
            print("خيار غير صالح ,حاول مرة اخري")
            continue

        show_bookings_for_service(bookings, choice)

        day = input("\nاختر يوم من :(الاحد - الخميس)").strip()
        if day not in Days:
            print("يجب اختيار يوم من القائمة")
            continue

        time = input("ختر وقت من :(1:00),(12:00),(11:00),(10:00),(9:00)").strip()
        if time not in Times:
            print("يجب اختيار وقت من القائمة")
            continue

        make_booking(bookings, choice, day, time)
        show_bookings_for_service(bookings, choice)


#تعريف الايام والمواعيد و الخدمات
Days = ['الاحد', 'الاثنين', 'الثلثاء', 'الاربعاء', 'الخميس']
Times = ['9:00','10:00','11:00','12:00','01:00']
MAX_BOOKINGS_PER_SLOT=10

SERVICES = {
    '1': 'اصدار رخصه سيارة اول مرة',
    '2': 'تجديد رخصه سيارة',
    '3': 'اصدار رخصه قياده اول مرة',
    '4': 'تجديد رخصه قيادة',
    '5': 'اصدار بدل فاقد'
}

#انشاء جدول حجز
def initialize_bookings():
    bookings = {}
    for service in SERVICES:
        bookings[service] = {}
        for day in Days:
            bookings[service][day] = {}
            for time in Times:
                bookings [service][day][time] = 0
    return bookings

def display_services():
    print("\nالخدمات المتاحة:")
    for key , value in SERVICES.items():
        print(f"{key}. {value}")

def show_bookings_for_service(bookings, service_id):
    service_name = SERVICES[service_id]
    print(f"حجوزات {service_name}:")
    for day in Days:
        print(f"{day}:")
        for time in Times:
            count = bookings[service_id][day][time]
            print(f" {time} - {count}/10 حجوزات")

def make_booking(bookings, service_id, day, time):
    if bookings[service_id][day][time] < MAX_BOOKINGS_PER_SLOT:
        bookings[service_id][day][time] += 1
        service_name = SERVICES[service_id]
        print(f"تم حجز {service_name} في {day} في {time}.")
    else:
      print("هذا الموعد ممتلى بالفعل ")


def main():
    bookings = initialize_bookings()

    while True:
        display_services()
        choice = input ("\n اختر رقم الخدمه(او اكتب 'خروج' لانهاء البرنامج )").strip()
        if choice.lower() == 'خروج':
            print("شكرا لاستخدامك النظام")
            break

        if choice not in SERVICES:
            print("خيار غير صالح ,حاول مرة اخري")
            continue

        show_bookings_for_service(bookings, choice)

        day = input("\nاختر يوم من :(الاحد - الخميس)").strip()
        if day not in Days:
            print("يجب اختيار يوم من القائمة")
            continue

        time = input("ختر وقت من :(1:00),(12:00),(11:00),(10:00),(9:00)").strip()
        if time not in Times:
            print("يجب اختيار وقت من القائمة")
            continue

        make_booking(bookings, choice, day, time)
        show_bookings_for_service(bookings, choice)


if __name__ == "__main__":
    main()
# Out:
# الخدمات المتاحة:
# 1. اصدار رخصه سيارة اول مرة
# 2. تجديد رخصه سيارة
# 3. اصدار رخصه قياده اول مرة
# 4. تجديد رخصه قيادة
# 5. اصدار بدل فاقد
# حجوزات اصدار بدل فاقد:
# الاحد:
#  9:00 - 0/10 حجوزات
#  10:00 - 0/10 حجوزات
#  11:00 - 0/10 حجوزات
#  12:00 - 0/10 حجوزات
#  01:00 - 0/10 حجوزات
# الاثنين:
#  9:00 - 0/10 حجوزات
#  10:00 - 0/10 حجوزات
#  11:00 - 0/10 حجوزات
#  12:00 - 0/10 حجوزات
#  01:00 - 0/10 حجوزات
# الثلثاء:
#  9:00 - 0/10 حجوزات
#  10:00 - 0/10 حجوزات
#  11:00 - 0/10 حجوزات
#  12:00 - 0/10 حجوزات
#  01:00 - 0/10 حجوزات
# الاربعاء:
#  9:00 - 0/10 حجوزات
#  10:00 - 0/10 حجوزات
#  11:00 - 0/10 حجوزات
#  12:00 - 0/10 حجوزات
#  01:00 - 0/10 حجوزات
# الخميس:
#  9:00 - 0/10 حجوزات
#  10:00 - 0/10 حجوزات
#  11:00 - 0/10 حجوزات
#  12:00 - 0/10 حجوزات
#  01:00 - 0/10 حجوزات

# %%
# Out:
# 'اصدار بدل فاقد'
